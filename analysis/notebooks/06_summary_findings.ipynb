# %% [markdown]
# # 06 — Summary findings
#
# Verbatim bullets reused in `paper/sections/06_evaluation.tex`.

# %%
import sys
from pathlib import Path as _P
_root = _P.cwd()
while not (_root / 'pyproject.toml').exists() and _root != _root.parent:
    _root = _root.parent
if str(_root) not in sys.path:
    sys.path.insert(0, str(_root))
from analysis import ANALYSIS_DIR
print((ANALYSIS_DIR / 'SUMMARY.md').read_text(encoding='utf-8'))
# Out:
# # Phase-10 Summary
#
# One-paragraph TL;DR per research question. Generated by
# `analysis/scripts/run_all.py` from the Phase-9 raw outputs.
#
# ## RQ-1: Baseline isolation
# - 8 attacks analysed; **0** flagged significant after Bonferroni correction within boundary. Max |Cliff's δ| = 0.00.
#
# ## RQ-2: Cache dominance
# - Cache attacks account for **85.7%** of vulnerable-server leakage. One-sided z-test vs. 50%: z = 40.75, p = 0.0000.
#
# ## RQ-3: Prompt-injection residual
# - 0/7 attacks on the secure server fell inside the [0.05, 0.30] bounded-residual corridor.
#
# ## RQ-4: Defense combo super-additivity
# - Paired Welch's t on (partial − full) leakage differences: t = 22.80, one-sided p = 0.0000.

# %% [markdown]
# - RQ-1 run_id: `exp-rq1-baseline`
# - RQ-2 run_id: `exp-rq2-cache`
# - RQ-3 run_id: `exp-rq3-injection`
# - RQ-4 run_id: `exp-rq4-defense`
